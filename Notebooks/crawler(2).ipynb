    "赤沙之杖",
    "天空之脊",
    "和璞鸢",
    "贯虹之槊",
    "息灾"
]
character_list = [
    "白术",
    "迪希雅",
    "艾尔海森",
    "流浪者",
    "纳西妲",
    "妮露",
    "赛诺",
    "提纳里",
    "夜兰",
    "神里绫人",
    "八重神子",
    "申鹤",
    "荒泷一斗",
    "珊瑚宫心海",
    "埃洛伊",
    "雷电将军",
    "宵宫",
    "神里绫华",
    "枫原万叶",
    "优菈",
    "胡桃",
    "魈",
    "甘雨",
    "阿贝多",
    "钟离",
    "达达利亚",
    "可莉",
    "温迪",
    "七七",
    "刻晴",
    "旅行者",
    "派蒙",
    "旅行者/草",
    "旅行者/岩",
    "旅行者/雷",
    "旅行者/风",
    "琴",
    "莫娜",
    "迪卢克",
    "绮良良",
    "卡维",
    "米卡",
    "瑶瑶",
    "珐露珊",
    "莱依拉",
    "坎蒂丝",
    "多莉",
    "柯莱",
    "鹿野院平藏",
    "久岐忍",
    "云堇",
    "五郎",
    "托马",
    "九条裟罗",
    "早柚",
    "烟绯",
    "罗莎莉亚",
    "辛焱",
    "迪奥娜",
    "丽莎",
    "凝光",
    "凯亚",
    "北斗",
    "安柏",
    "班尼特",
    "砂糖",
    "芭芭拉",
    "菲谢尔",
    "行秋",
    "诺艾尔",
    "重云",
    "雷泽",
    "香菱"
]
artifact_list = ["冒险家", "幸运儿", "游医", "战狂", "学士", "流放者", "行者之心", "祭冰之人", "奇迹", "勇士之心", "祭火之人", "教官", "赌徒", "祭水之人", "武人", "祭雷之人", "守护之心", "逆飞的流星", "乐园遗落之花", "流浪大地的乐团", "辰砂往生录", "平息鸣雷的尊者", "千岩牢固", "渡过烈火的贤人", "被怜爱的少女", "水仙之梦", "来歆余响", "绝缘之旗印", "炽烈的炎之魔女", "花海甘露之光", "角斗士的终幕礼", "深林的记忆", "追忆之注连", "如雷的盛怒", "冰风迷途的勇士", "饰金之梦", "染血的骑士道", "华馆梦醒形骸记", "沉沦之心", "昔日宗室之仪", "悠古的磐岩", "沙上楼阁史话", "海染砗磲", "苍白之火", "翠绿之影"]
event_list = ["蒙德·地理", "蒙德·生态", "风花节", "羽球节", "归风佳酿节", "东风守护·特瓦林", "西风守护·西风骑士团", "温妮莎", "炎之魔女", "染血骑士", "鲁斯坦", "迭卡拉庇安", "璃月·地理", "璃月·生态", "海灯节", "逐月节", "若陀龙王", "夜叉", "归终", "盐之魔神", "铜雀", "移霄导天真君", "稻妻·地理", "稻妻·生态", "三奉行", "浅濑响", "昆布丸", "赤穗百目鬼", "狐斋宫", "笹百合", "御舆千代", "须弥·地理", "须弥·生态", "须弥教令院", "镀金旅团", "花神诞日", "赤王", "大慈树王", "花神", "冰炉节", "愚人众", "深渊教团", "戴因斯雷布", "遗迹守卫", "黑蛇众", "白鹄骑士", "渊下宫·地理", "太阳之子", "蒙德", "璃月", "稻妻", "须弥", "至冬", "坎瑞亚", "白夜国"]
尔', '叶名山薰', '叶卡捷琳娜', '史蒂文斯', '古谷升', '古田', '古拉布吉尔', '古思塔斯普', '古德温', '古尔根', '口渴夜鸦', '双叶', '厄桑', '卯师傅', '卢卡', '卢克', '卡齐姆', '卡里玛', '卡里尔', '卡琵莉亚', '卡玛尔', '卡桑', '卡格姆尼', '卡斯帕', '卡姆拉', '卡姆兰', '卡塔扬', '卡乌斯', '卜劳恩', '博行', '博来', '博彦', '博尼法兹', '卓英', '卉卉', '千叶', '劳伦斯', '努查赫', '加萨尼', '加福尔', '加斯顿', '加扎里', '利文斯通博士', '判官儿', '凯瑟琳（稻妻）', '凯瑟琳（蒙德）', '凯瑟琳（须弥）', '凯瑟琳（璃月）', '凯撒', '凯叔', '凯万', '几原凯', '凉子', '冈崎陆斗', '冈崎绘里香', '内海', '内森', '内尔敏', '内嘉', '其老爷', '关宏', '关垂', '兰非拉', '兰难世', '兰随尼', '兰陀娑', '兰阿帕斯', '兰那库拉', '兰迦鲁', '兰达', '兰贡迪', '兰萨卡', '兰茶荼', '兰般度', '兰耶师', '兰耶娑', '兰羯磨', '兰纳迦', '兰纳真', '兰百梨迦', '兰玛尼', '兰犍多', '兰沙恭', '兰梨娄', '兰拉迦', '兰帕卡提', '兰巴德', '兰卑浮', '兰加惟', '兰利遮', '兰修提袈', '兰伽卢', '兰伊舍', '六指乔瑟', '公明', '克雷门斯', '克里托夫', '克罗丽丝', '元鸿', '信盛', '保琳', '侯赛因', '佩佩', '佑旭', '佐赫蕾', '佐藤', '佐佐木', '伯特兰', '伯桓子', '伯恩哈德', '优素福', '优律', '优丹', '伍德', '伊达里', '伊达', '伊萨米', '伊萨克', '伊泽姆', '伊拉杰', '伊拉兹', '伊扎德', '伊尔佳', '伊娜姆', '伊凡诺维奇', '伊丽丝', '仲林', '今谷三郎', '仁羽', '亨利莫顿', '亚历山德拉', '井上', '五百藏', '云淡', '乾子', '九条镰治', '九条政仁', '乔瑟夫', '乔尔', '乔姨', '乌达德', '乌纳因', '乌格威', '乌尔班', '乌尔法', '乌姆', '久美', '久利须', '乃亚卜', '丽玛', '丹迪', '中野', '中西', '严备', '东雅', '东升', '东东', '上杉', '三田', '三浦', '三河茜', '万货通', '七郎', '一阔', '一然', '一柱', '一成', '一弦', '「金龟奇术番长」', '「造笼师」']

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
import os
os.environ['https_proxy'] = ''
from urllib.parse import quote

# %%
urls = ['https://wiki.biligame.com/ys/' + quote(weapon) for weapon in weapon_list]

# %%
responses = [requests.get(url) for url in urls]

# %%
print(len(responses))
print(len(weapon_list))

# %%
for i in range(len(responses)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'id': 'mc_collapse-1'})
    # write all div.text into a txt
    with open('data2.txt', 'a') as f:
        f.write(weapon_list[i]+ '的故事\n')
    for div in divs:
        with open('data2.txt', 'a') as f:
            f.write(re.sub('\n\s*\n', '\n', div.text))
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = ['https://wiki.biligame.com/ys/' + quote(character) for character in character_list]
responses = [requests.get(url) for url in urls]

# %%
for i in range(len(responses)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('table', {'class': 'wikitable', 'style': 'width: 100%; margin: 0'})
    # write all div.text into a txt
    if len(divs) == 0:
        continue
    divs = divs[0]
    divs = divs.find_all('td')
    with open('data2.txt', 'a') as f:
        f.write(character_list[i] + '的故事\n')
        # print(character_list[i] + '\n')
    for div in divs:
        with open('data2.txt', 'a') as f:
            f.write(re.sub('\n\s*\n', '\n', div.text))
            # print(div.text)
    with open('data2.txt', 'a') as f:
        f.write('\n\n')
        # print('\n')

# %%
urls = ['https://wiki.biligame.com/ys/' + str(artifact) for artifact in artifact_list]
responses = [requests.get(url) for url in urls]

# %%
for i in range(len(responses)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'story'})
    with open('data2.txt', 'a') as f:
        f.write(artifact_list[i] + '的故事\n')
    for div in divs:
        with open('data2.txt', 'a') as f:
            f.write(re.sub('\n\s*\n', '\n', div.text))
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = ['https://wiki.biligame.com/ys/' + str(event) for event in event_list]
responses = [requests.get(url) for url in urls]

# %%
import re

# %%
for i in range(len(responses)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'mw-parser-output'})
    with open('data2.txt', 'a') as f:
        f.write('关于' + event_list[i] + '\n')
    for div in divs:
        # with open('data.txt', 'a') as f:
        #     f.write(div.text)
        for p in div.find_all('p'):
            print(re.sub(r'\[\d+\]', '', p.text))
            with open('data2.txt', 'a') as f:
                text = re.sub(r'\[\d+\]', '', p.text)
                text = re.sub('\n\s*\n+', '\n', text)
                if(text == '\n'):
                    continue
                f.write(re.sub('\n\s*\n+', '\n', text))
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = ['https://wiki.biligame.com/ys/' + str(chuanshuo) for chuanshuo in chuanshuo_list]
responses = [requests.get(url) for url in urls]

# %%
for i in range(len(responses)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'toc-sticky'})
    if divs == []:
        divs = soup.find_all('div', {'class': 'mw-parser-output'})
    if divs == []:
        continue
    with open('data2.txt', 'a') as f:
        f.write('任务 ' + chuanshuo_list[i]+'\n')
    for div in divs:
        li = div.find_all('li')
        for i in li:
            #不是以数字开头的话就输出
            if len(i.text) == 0:
                continue
            if not i.text[0].isdigit():
                with open('data2.txt', 'a') as f:
                    f.write(re.sub('\n\s*\n+', '\n', i.text) + '\n')
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = ['https://wiki.biligame.com/ys/' + str(moshen) for moshen in moshen_list]
responses = [requests.get(url) for url in urls]

# %%
for i in range(len(responses)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'toc-sticky'})
    if divs == []:
        divs = soup.find_all('div', {'class': 'mw-parser-output'})
    if divs == []:
        continue
    with open('data2.txt', 'a') as f:
        f.write('任务 ' + moshen_list[i]+'\n')
    for div in divs:
        li = div.find_all('li')
        for i in li:
            #不是以数字开头的话就输出
            if len(i.text) == 0:
                continue
            if not i.text[0].isdigit():
                with open('data2.txt', 'a') as f:
                    f.write(re.sub('\n\s*\n+', '\n', i.text) + '\n')
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = 'https://wiki.biligame.com/ys/世界任务'
response = requests.get(urls)

# %%
world_list = []

# %%
soup = BeautifulSoup(response.text, 'html.parser') 
divs = soup.find_all('span', {'class': 'home-an1'})
for div in divs:
    world_list.append((div.text).split('\xa0')[0])
print(world_list)

# %%
import time

# %%
urls = ['https://wiki.biligame.com/ys/' + str(world) for world in world_list]
responses = [requests.get(url) for url in urls[:230]]
time.sleep(10)
responses += [requests.get(url) for url in urls[230:]]

# %%
len(urls)

# %%
for i in range(len(world_list)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'toc-sticky'})
    if divs == []:
        divs = soup.find_all('div', {'class': 'mw-parser-output'})
    if divs == []:
        continue
    with open('data2.txt', 'a') as f:
        f.write('任务 ' + world_list[i]+'\n')
    for div in divs:
        li = div.find_all('li')
        for i in li:
            #不是以数字开头的话就输出
            if len(i.text) == 0:
                continue
            if not i.text[0].isdigit():
                with open('data2.txt', 'a') as f:
                    f.write(re.sub('\n\s*\n+', '\n', i.text) + '\n')
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = ['https://wiki.biligame.com/ys/' + str(monster) for monster in monster_list]
responses = [requests.get(url) for url in urls]

# %%
for i in range(len(monster_list)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'wiki-bot'})
    with open('data2.txt', 'a') as f:
        f.write('关于 ' + monster_list[i]+'\n')
    for div in divs:
        text = div.find_all('p')
        if len(text) == 0:
            continue
        with open('data2.txt', 'a') as f:
            f.write(re.sub('\n\s*\n+', '\n', text[0].text) + '\n')
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
npc_list = []

# %%
urls = 'https://wiki.biligame.com/ys/NPC图鉴'
response = requests.get(urls)   
soup = BeautifulSoup(response.text, 'html.parser') 
divs = soup.find_all('div', {'class': 'n'})
for div in divs:
    npc_list.append(div.text)

# %%
print(len(npc_list))

# %%
urls = ['https://wiki.biligame.com/ys/' + str(npc) for npc in npc_list]
responses = [requests.get(url) for url in urls[:200]]
print('200')
time.sleep(10)
responses += [requests.get(url) for url in urls[200:400]]
print('400')
time.sleep(10)
responses += [requests.get(url) for url in urls[400:600]]
print('600')
time.sleep(10)
responses += [requests.get(url) for url in urls[600:800]]
print('800')
time.sleep(10)

# %%
responses += [requests.get(url) for url in urls[800:1000]]
print('1000')
time.sleep(10)

# %%
len(responses)

# %%
for i in range(len(monster_list)):
    soup = BeautifulSoup(responses[i].text, 'html.parser') 
    divs = soup.find_all('div', {'class': 'npcPlotFrame'})
    # print(divs[0].text)
    if len(divs) == 0:
        continue
    with open('data2.txt', 'a') as f:
        f.write('关于 ' + npc_list[i])
    with open('data2.txt', 'a') as f:
        f.write(re.sub('\n\s*\n+', '\n', divs[0].text) + '\n')
    with open('data2.txt', 'a') as f:
        f.write('\n\n')

# %%
urls = 'https://wiki.biligame.com/ys/野生生物一览'
response = requests.get(urls)

# %%
soup = BeautifulSoup(response.text, 'html.parser') 
divs = soup.find_all('tr', {'class': 'divsort bwiki-collection'})
for div in divs:
    print(div['data-collection'])
    print(div.find_all('td')[4].text)

# %%
import ast

# %%
url = "https://www.pixiv.net/novel/show.php?id=19058512"

# %%
response = requests.get(url)

# %%
print(response.text)

# %%
soup = BeautifulSoup(response.text, 'html.parser') 
divs = soup.find_all("meta")
for div in divs:
    print(div['content'])
    print('=============')
    try:
        res = json.loads(div['content'])
        print(res['content'])
    except:
        continue

# %%
print(divs[-1]['content'])

# %%
url = "https://xinjinjumin5141525.lofter.com/post/77be3c0f_2b9f2af26"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser') 
divs = soup.find_all('p')
for div in divs:
    print(div.text)
